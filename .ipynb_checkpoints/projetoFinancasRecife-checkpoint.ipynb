# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
end_despesas = './dados_prefeitura/recife-dados-despesas-2017.csv'
end_receitas = './dados_prefeitura/recife-dados-receitas-2017.csv'

# Dataframe com os dados das despesas
despesas = pd.read_csv(end_despesas, sep='\t',delimiter=';',decimal=',')
desp_df = pd.DataFrame(despesas)
desp_df.head()
# Out:
#    ano_movimentacao  mes_movimentacao  orgao_codigo            orgao_nome  \
# 0              2017                 3            10  GABINETE DO PREFEITO
# 1              2017                 4            10  GABINETE DO PREFEITO
# 2              2017                 7            10  GABINETE DO PREFEITO
# 3              2017                11            10  GABINETE DO PREFEITO
# 4              2017                 6            10  GABINETE DO PREFEITO
#
#   unidade_codigo                                 unidade_nome  \
# 0          10.01  GABINETE DO PREFEITO - ADMINISTRAÇÃO DIRETA
# 1          10.01  GABINETE DO PREFEITO - ADMINISTRAÇÃO DIRETA
# 2          10.01  GABINETE DO PREFEITO - ADMINISTRAÇÃO DIRETA
# 3          10.01  GABINETE DO PREFEITO - ADMINISTRAÇÃO DIRETA
# 4          10.01  GABINETE DO PREFEITO - ADMINISTRAÇÃO DIRETA
#
#    categoria_economica_codigo categoria_economica_nome  grupo_despesa_codigo  \
# 0                           3       DESPESAS CORRENTES                     1
# 1                           3       DESPESAS CORRENTES                     1
# 2                           3       DESPESAS CORRENTES                     1
# 3                           3       DESPESAS CORRENTES                     1
# 4                           3       DESPESAS CORRENTES                     1
#
#            grupo_despesa_nome    ...      empenho_numero subempenho  \
# 0  PESSOAL E ENCARGOS SOCIAIS    ...                  43         83
# 1  PESSOAL E ENCARGOS SOCIAIS    ...                  43         84
# 2  PESSOAL E ENCARGOS SOCIAIS    ...                  43         87
# 3  PESSOAL E ENCARGOS SOCIAIS    ...                  43         91
# 4  PESSOAL E ENCARGOS SOCIAIS    ...                  44         86
#
#    indicador_subempenho credor_codigo           credor_nome  \
# 0                     x             0  CREDOR NÃO INFORMADO
# 1                     x             0  CREDOR NÃO INFORMADO
# 2                     x             0  CREDOR NÃO INFORMADO
# 3                     x             0  CREDOR NÃO INFORMADO
# 4                     x             0  CREDOR NÃO INFORMADO
#
#   modalidade_licitacao_codigo  modalidade_licitacao_nome valor_empenhado  \
# 0                           0              NÃO INFORMADA       160613.59
# 1                           0              NÃO INFORMADA       159933.78
# 2                           0              NÃO INFORMADA        77521.68
# 3                           0              NÃO INFORMADA        86559.28
# 4                           0              NÃO INFORMADA         2855.30
#
#    valor_liquidado valor_pago
# 0        160613.59  160613.59
# 1        159933.78  159933.78
# 2         77521.68   77521.68
# 3         86559.28   86559.28
# 4          2855.30    2855.30
#
# [5 rows x 39 columns]

# %%
desp_df.dtypes
# Out:
# ano_movimentacao                 int64
# mes_movimentacao                 int64
# orgao_codigo                     int64
# orgao_nome                      object
# unidade_codigo                  object
# unidade_nome                    object
# categoria_economica_codigo       int64
# categoria_economica_nome        object
# grupo_despesa_codigo             int64
# grupo_despesa_nome              object
# modalidade_aplicacao_codigo      int64
# modalidade_aplicacao_nome       object
# elemento_codigo                  int64
# elemento_nome                   object
# subelemento_codigo               int64
# subelemento_nome                object
# funcao_codigo                    int64
# funcao_nome                     object
# subfuncao_codigo                 int64
# subfuncao_nome                  object
# programa_codigo                  int64
# programa_nome                   object
# acao_codigo                      int64
# acao_nome                       object
# fonte_recurso_codigo             int64
# fonte_recurso_nome              object
# empenho_ano                      int64
# empenho_modalidade_nome         object
# empenho_modalidade_codigo        int64
# empenho_numero                   int64
# subempenho                       int64
# indicador_subempenho            object
# credor_codigo                    int64
# credor_nome                     object
# modalidade_licitacao_codigo      int64
# modalidade_licitacao_nome       object
# valor_empenhado                float64
# valor_liquidado                float64
# valor_pago                     float64
# dtype: object

# %%
# Excluir colunas redundantes
desp_colunas_excluir = ['orgao_codigo','unidade_codigo','categoria_economica_codigo','grupo_despesa_codigo','modalidade_aplicacao_codigo','elemento_codigo','subelemento_codigo','funcao_codigo','subfuncao_codigo','programa_codigo','acao_codigo','fonte_recurso_codigo','empenho_modalidade_codigo','credor_codigo','modalidade_licitacao_codigo']
despesas_df = desp_df.drop(desp_colunas_excluir, axis=1)

# Ajuste de tipos numericos
despesas_df['valor_liquidado'] = despesas_df.valor_liquidado.astype('float64')
despesas_df['valor_empenhado'] = despesas_df.valor_empenhado.astype('float64')
despesas_df['valor_pago'] = despesas_df.valor_pago.astype('float64')

print(despesas_df.dtypes)

despesas_df.isnull().sum()
# Out:
# ano_movimentacao               int64
# mes_movimentacao               int64
# orgao_nome                    object
# unidade_nome                  object
# categoria_economica_nome      object
# grupo_despesa_nome            object
# modalidade_aplicacao_nome     object
# elemento_nome                 object
# subelemento_nome              object
# funcao_nome                   object
# subfuncao_nome                object
# programa_nome                 object
# acao_nome                     object
# fonte_recurso_nome            object
# empenho_ano                    int64
# empenho_modalidade_nome       object
# empenho_numero                 int64
# subempenho                     int64
# indicador_subempenho          object
# credor_nome                   object
# modalidade_licitacao_nome     object
# valor_empenhado              float64
# valor_liquidado              float64
# valor_pago                   float64
# dtype: object
# ano_movimentacao             0
# mes_movimentacao             0
# orgao_nome                   0
# unidade_nome                 0
# categoria_economica_nome     0
# grupo_despesa_nome           0
# modalidade_aplicacao_nome    0
# elemento_nome                0
# subelemento_nome             0
# funcao_nome                  0
# subfuncao_nome               0
# programa_nome                0
# acao_nome                    0
# fonte_recurso_nome           0
# empenho_ano                  0
# empenho_modalidade_nome      0
# empenho_numero               0
# subempenho                   0
# indicador_subempenho         0
# credor_nome                  0
# modalidade_licitacao_nome    0
# valor_empenhado              0
# valor_liquidado              0
# valor_pago                   0
# dtype: int64

# %%
despesas_df.describe()
# Out:
#        ano_movimentacao  mes_movimentacao   empenho_ano  empenho_numero  \
# count           94178.0      94178.000000  94178.000000    94178.000000
# mean             2017.0          7.302406   2016.986929     1214.616036
# std                 0.0          3.448565      0.113579     1365.289435
# min              2017.0          1.000000   2016.000000        1.000000
# 25%              2017.0          4.000000   2017.000000      185.000000
# 50%              2017.0          7.000000   2017.000000      630.000000
# 75%              2017.0         11.000000   2017.000000     1906.000000
# max              2017.0         12.000000   2017.000000     5837.000000
#
#          subempenho  valor_empenhado  valor_liquidado    valor_pago
# count  94178.000000     9.417800e+04     9.417800e+04  9.417800e+04
# mean       6.851027     4.506868e+04     4.476453e+04  4.448439e+04
# std       20.426686     8.617238e+05     4.321593e+05  4.307524e+05
# min        0.000000    -5.891101e+07    -5.800000e+06 -5.800000e+06
# 25%        0.000000     0.000000e+00     0.000000e+00  0.000000e+00
# 50%        0.000000     0.000000e+00     3.843000e+02  3.840000e+02
# 75%        3.000000     1.800000e+03     5.000000e+03  5.000000e+03
# max      159.000000     9.885700e+07     3.292600e+07  3.292600e+07

# %%
# Dados da Receita da Prefeitura
rec = pd.read_csv(end_receitas, sep='\t',delimiter=';',decimal=',')
rec_df = pd.DataFrame(rec)
rec_df.head()
# Out:
#     ano  mes  mes_nome  orgao_codigo              orgao_nome unidade_codigo  \
# 0  2017    1   Janeiro            15  SECRETARIA DE FINANÇAS          15.01
# 1  2017    1   Janeiro            15  SECRETARIA DE FINANÇAS          15.01
# 2  2017    1   Janeiro            15  SECRETARIA DE FINANÇAS          15.01
# 3  2017    1   Janeiro            15  SECRETARIA DE FINANÇAS          15.01
# 4  2017   11  Novembro            15  SECRETARIA DE FINANÇAS          15.01
#
#                                     unidade_nome  fonte_recurso_codigo  \
# 0  SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO DIRETA                   100
# 1  SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO DIRETA                   100
# 2  SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO DIRETA                   103
# 3  SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO DIRETA                   115
# 4  SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO DIRETA                   117
#
#                      fonte_recurso_nome  categoria_receita_codigo  \
# 0  RECURSOS ORDINÁRIOS - NÃO VINCULADOS                         1
# 1  RECURSOS ORDINÁRIOS - NÃO VINCULADOS                         1
# 2                  OPERAÇÕES DE CRÉDITO                         1
# 3          SAÚDE - VIGILÂNCIA SANITÁRIA                         1
# 4                 TRANSFERÊNCIAS DO FDS                         1
#
#           ...         alinea_receita_codigo  \
# 0         ...                             0
# 1         ...                             0
# 2         ...                             0
# 3         ...                             0
# 4         ...                             0
#
#                        alinea_receita_nome subalinea_receita_codigo  \
# 0                               DIVIDENDOS                        0
# 1  TRANSFERENCIAS DE INSTITUICOES PRIVADAS                        0
# 2       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                        0
# 3       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                        0
# 4       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                        0
#
#                     subalinea_receita_nome receita_local_codigo  \
# 0                               DIVIDENDOS                    0
# 1  TRANSFERÊNCIAS DE INSTITUIÇÕES PRIVADAS                    0
# 2       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                    0
# 3       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                    0
# 4       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                    0
#
#                              receita_local_nome receita_prevista  \
# 0  SEM PREVISÃO INICIAL PARA ESSA CLASSIFICAÇÃO           1000.0
# 1  SEM PREVISÃO INICIAL PARA ESSA CLASSIFICAÇÃO        6816000.0
# 2  SEM PREVISÃO INICIAL PARA ESSA CLASSIFICAÇÃO         347000.0
# 3  SEM PREVISÃO INICIAL PARA ESSA CLASSIFICAÇÃO          52000.0
# 4  SEM PREVISÃO INICIAL PARA ESSA CLASSIFICAÇÃO              0.0
#
#    receita_prevista_acrescimo receita_prevista_atualizada  receita_arrecadada
# 0                         0.0                      1000.0                 0.0
# 1                         0.0                   6816000.0                 0.0
# 2                         0.0                    347000.0                 0.0
# 3                         0.0                     52000.0                 0.0
# 4                      7000.0                      7000.0                 0.0
#
# [5 rows x 27 columns]

# %%
print(rec_df.dtypes)
# Out:
# ano                              int64
# mes                              int64
# mes_nome                        object
# orgao_codigo                     int64
# orgao_nome                      object
# unidade_codigo                  object
# unidade_nome                    object
# fonte_recurso_codigo             int64
# fonte_recurso_nome              object
# categoria_receita_codigo         int64
# categoria_receita_nome          object
# fonte_origem_receita_codigo      int64
# fonte_origem_receita_nome       object
# subfonte_receita_codigo          int64
# subfonte_receita_nome           object
# rubrica_receita_codigo           int64
# rubrica_receita_nome            object
# alinea_receita_codigo            int64
# alinea_receita_nome             object
# subalinea_receita_codigo         int64
# subalinea_receita_nome          object
# receita_local_codigo             int64
# receita_local_nome              object
# receita_prevista               float64
# receita_prevista_acrescimo     float64
# receita_prevista_atualizada    float64
# receita_arrecadada             float64
# dtype: object

# %%
# Excluir colunas redundantes
rec_colunas_excluir = ['mes','orgao_codigo','unidade_codigo','fonte_recurso_codigo','categoria_receita_codigo','receita_local_nome','fonte_origem_receita_codigo','subfonte_receita_codigo','rubrica_receita_codigo','alinea_receita_codigo','subalinea_receita_codigo','subalinea_receita_codigo','receita_local_codigo']
receita_df = rec_df.drop(rec_colunas_excluir, axis=1)

print(receita_df.dtypes)

receita_df.isnull().sum()
# Out:
# ano                              int64
# mes_nome                        object
# orgao_nome                      object
# unidade_nome                    object
# fonte_recurso_nome              object
# categoria_receita_nome          object
# fonte_origem_receita_nome       object
# subfonte_receita_nome           object
# rubrica_receita_nome            object
# alinea_receita_nome             object
# subalinea_receita_nome          object
# receita_prevista               float64
# receita_prevista_acrescimo     float64
# receita_prevista_atualizada    float64
# receita_arrecadada             float64
# dtype: object
# ano                            0
# mes_nome                       0
# orgao_nome                     0
# unidade_nome                   0
# fonte_recurso_nome             0
# categoria_receita_nome         0
# fonte_origem_receita_nome      0
# subfonte_receita_nome          0
# rubrica_receita_nome           0
# alinea_receita_nome            0
# subalinea_receita_nome         0
# receita_prevista               0
# receita_prevista_acrescimo     0
# receita_prevista_atualizada    0
# receita_arrecadada             0
# dtype: int64

# %%
receita_df.describe()
# Out:
#           ano          mes  receita_prevista  receita_prevista_acrescimo  \
# count  4406.0  4406.000000      4.406000e+03                4.406000e+03
# mean   2017.0     6.411030      1.360191e+06                8.925208e+04
# std       0.0     3.561448      2.341404e+07                2.215461e+06
# min    2017.0     1.000000     -1.599400e+08                0.000000e+00
# 25%    2017.0     3.000000      0.000000e+00                0.000000e+00
# 50%    2017.0     6.000000      0.000000e+00                0.000000e+00
# 75%    2017.0    10.000000      0.000000e+00                0.000000e+00
# max    2017.0    12.000000      7.997000e+08                1.274884e+08
#
#        receita_prevista_atualizada  receita_arrecadada
# count                 4.406000e+03        4.406000e+03
# mean                  1.449443e+06        1.036916e+06
# std                   2.351345e+07        5.831553e+06
# min                  -1.599400e+08       -1.644545e+07
# 25%                   0.000000e+00        6.500000e+02
# 50%                   0.000000e+00        1.137975e+04
# 75%                   0.000000e+00        1.699012e+05
# max                   7.997000e+08        1.290000e+08

# %%
# Gastos de acordo com sua função
gasto_por_orgao = despesas_df.groupby(['funcao_nome']).agg({'valor_pago':'sum'})

gasto_por_orgao
# Out:
#                          valor_pago
# funcao_nome
# ADMINISTRAÇÃO          3.971512e+08
# ASSISTÊNCIA SOCIAL     6.063588e+07
# CIÊNCIA E TECNOLOGIA   7.127305e+05
# COMÉRCIO E SERVIÇOS    4.201392e+07
# CULTURA                9.331361e+07
# DESPORTO E LAZER       1.988366e+07
# DIREITOS DA CIDADANIA  7.242814e+07
# EDUCAÇÃO               8.179947e+08
# ENCARGOS ESPECIAIS     2.290456e+08
# ESSENCIAL À JUSTIÇA    4.194922e+07
# GESTÃO AMBIENTAL       2.045162e+07
# HABITAÇÃO              8.664390e+05
# PREVIDÊNCIA SOCIAL     4.580120e+08
# SANEAMENTO             6.886084e+07
# SAÚDE                  1.063713e+09
# TRABALHO               2.385739e+06
# URBANISMO              8.000328e+08

# %%
# Substituir codigo por nomes de mes
meses = {1:'Janeiro',2:'Fevereiro',3:'Março',4:'Abril',5:'Maio',6:'Junho',7:'Julho',8:'Agosto',9:'Setembro',10:'Outubro',11:'Novembro',12:'Dezembro'}

mes_nome = []

for mes in despesas_df['mes_movimentacao']:
    mes_nome.append(mes)
    
lista = [meses.get(item,item) for item in mes_nome]

despesas_df['mes_movimentacao'] = lista

lista_meses = ['Janeiro','Fevereiro','Março','Abril','Maio','Junho','Julho','Agosto','Setembro','Outubro','Novembro','Dezembro']

# Analisar qual o mês com mais gasto

gasto_por_mes = despesas_df.groupby(['mes_movimentacao']).agg({'valor_pago':'sum'})

receita_por_mes = receita_df.groupby(['mes_nome']).agg({'receita_arrecadada':'sum'})

comp_df = pd.concat([gasto_por_mes,receita_por_mes],axis=1,sort=False)

comp_df.plot.bar()
# gasto_por_mes.plot.bar()

# receita_por_mes.plot.bar()

# %%
gasto_por_grupos = despesas_df.groupby(['grupo_despesa_nome']).agg({'valor_pago':'sum'})

gasto_por_grupos.plot.barh()

# %% [markdown]
# Despesas correntes são as despesas com pessoal e encargos sociais, juros e encargos da dívida, e outras despesas correntes
# não enquadradas nos itens anteriores e voltadas para manter uma atividade do serviço público. E as despesas de capital são
# investimentos, inversões financeiras e amortização da dívida. Investimentos são dotações aplicadas em obras, aquisição de instalações, equipamentos, material permanente e constituição ou aumento de capital de empresas que não sejam de caráter comercial ou financeiro.
