# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re
import csv

# %%
end_despesas = './dados_prefeitura/recife-dados-despesas-2017.csv'
end_receitas = './dados_prefeitura/recife-dados-receitas-2017.csv'

despesas = pd.read_csv(end_despesas, sep='\t',delimiter=';')
despesas_df = pd.DataFrame(despesas)
despesas_df.head()
# Out:
#    ano_movimentacao  mes_movimentacao  orgao_codigo            orgao_nome  \
# 0              2017                 3            10  GABINETE DO PREFEITO
# 1              2017                 4            10  GABINETE DO PREFEITO
# 2              2017                 7            10  GABINETE DO PREFEITO
# 3              2017                11            10  GABINETE DO PREFEITO
# 4              2017                 6            10  GABINETE DO PREFEITO
#
#    unidade_codigo                                 unidade_nome  \
# 0           10.01  GABINETE DO PREFEITO - ADMINISTRAÇÃO DIRETA
# 1           10.01  GABINETE DO PREFEITO - ADMINISTRAÇÃO DIRETA
# 2           10.01  GABINETE DO PREFEITO - ADMINISTRAÇÃO DIRETA
# 3           10.01  GABINETE DO PREFEITO - ADMINISTRAÇÃO DIRETA
# 4           10.01  GABINETE DO PREFEITO - ADMINISTRAÇÃO DIRETA
#
#    categoria_economica_codigo categoria_economica_nome  grupo_despesa_codigo  \
# 0                           3       DESPESAS CORRENTES                     1
# 1                           3       DESPESAS CORRENTES                     1
# 2                           3       DESPESAS CORRENTES                     1
# 3                           3       DESPESAS CORRENTES                     1
# 4                           3       DESPESAS CORRENTES                     1
#
#            grupo_despesa_nome    ...      empenho_numero subempenho  \
# 0  PESSOAL E ENCARGOS SOCIAIS    ...                  43         83
# 1  PESSOAL E ENCARGOS SOCIAIS    ...                  43         84
# 2  PESSOAL E ENCARGOS SOCIAIS    ...                  43         87
# 3  PESSOAL E ENCARGOS SOCIAIS    ...                  43         91
# 4  PESSOAL E ENCARGOS SOCIAIS    ...                  44         86
#
#    indicador_subempenho credor_codigo           credor_nome  \
# 0                     x             0  CREDOR NÃO INFORMADO
# 1                     x             0  CREDOR NÃO INFORMADO
# 2                     x             0  CREDOR NÃO INFORMADO
# 3                     x             0  CREDOR NÃO INFORMADO
# 4                     x             0  CREDOR NÃO INFORMADO
#
#   modalidade_licitacao_codigo  modalidade_licitacao_nome valor_empenhado  \
# 0                           0              NÃO INFORMADA       160613,59
# 1                           0              NÃO INFORMADA       159933,78
# 2                           0              NÃO INFORMADA        77521,68
# 3                           0              NÃO INFORMADA        86559,28
# 4                           0              NÃO INFORMADA         2855,30
#
#    valor_liquidado valor_pago
# 0        160613,59  160613,59
# 1        159933,78  159933,78
# 2         77521,68   77521,68
# 3         86559,28   86559,28
# 4          2855,30    2855,30
#
# [5 rows x 39 columns]

# %%
receita = pd.read_csv(end_receitas, sep='\t',delimiter=';')
receita_df = pd.DataFrame(receita)
receita_df.head()
# Out:
#     ano  mes  mes_nome  orgao_codigo              orgao_nome  unidade_codigo  \
# 0  2017    1   Janeiro            15  SECRETARIA DE FINANÇAS           15.01
# 1  2017    1   Janeiro            15  SECRETARIA DE FINANÇAS           15.01
# 2  2017    1   Janeiro            15  SECRETARIA DE FINANÇAS           15.01
# 3  2017    1   Janeiro            15  SECRETARIA DE FINANÇAS           15.01
# 4  2017   11  Novembro            15  SECRETARIA DE FINANÇAS           15.01
#
#                                     unidade_nome  fonte_recurso_codigo  \
# 0  SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO DIRETA                   100
# 1  SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO DIRETA                   100
# 2  SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO DIRETA                   103
# 3  SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO DIRETA                   115
# 4  SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO DIRETA                   117
#
#                      fonte_recurso_nome  categoria_receita_codigo  \
# 0  RECURSOS ORDINÁRIOS - NÃO VINCULADOS                         1
# 1  RECURSOS ORDINÁRIOS - NÃO VINCULADOS                         1
# 2                  OPERAÇÕES DE CRÉDITO                         1
# 3          SAÚDE - VIGILÂNCIA SANITÁRIA                         1
# 4                 TRANSFERÊNCIAS DO FDS                         1
#
#           ...         alinea_receita_codigo  \
# 0         ...                             0
# 1         ...                             0
# 2         ...                             0
# 3         ...                             0
# 4         ...                             0
#
#                        alinea_receita_nome subalinea_receita_codigo  \
# 0                               DIVIDENDOS                        0
# 1  TRANSFERENCIAS DE INSTITUICOES PRIVADAS                        0
# 2       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                        0
# 3       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                        0
# 4       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                        0
#
#                     subalinea_receita_nome receita_local_codigo  \
# 0                               DIVIDENDOS                    0
# 1  TRANSFERÊNCIAS DE INSTITUIÇÕES PRIVADAS                    0
# 2       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                    0
# 3       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                    0
# 4       REMUNERAÇÃO DE DEPÓSITOS BANCÁRIOS                    0
#
#                              receita_local_nome receita_prevista  \
# 0  SEM PREVISÃO INICIAL PARA ESSA CLASSIFICAÇÃO          1000,00
# 1  SEM PREVISÃO INICIAL PARA ESSA CLASSIFICAÇÃO       6816000,00
# 2  SEM PREVISÃO INICIAL PARA ESSA CLASSIFICAÇÃO        347000,00
# 3  SEM PREVISÃO INICIAL PARA ESSA CLASSIFICAÇÃO         52000,00
# 4  SEM PREVISÃO INICIAL PARA ESSA CLASSIFICAÇÃO             0,00
#
#    receita_prevista_acrescimo receita_prevista_atualizada  receita_arrecadada
# 0                        0,00                     1000,00                0,00
# 1                        0,00                  6816000,00                0,00
# 2                        0,00                   347000,00                0,00
# 3                        0,00                    52000,00                0,00
# 4                     7000,00                     7000,00                0,00
#
# [5 rows x 27 columns]

# %%
despesas_df['valor_empenhado'] = despesas_df['valor_empenhado'].str.replace(',','.')
despesas_df['valor_liquidado'] = despesas_df['valor_liquidado'].str.replace(',','.')
despesas_df['valor_pago'] = despesas_df['valor_pago'].str.replace(',','.')

despesas_df['valor_liquidado'] = despesas_df.valor_liquidado.astype('float64')
despesas_df['valor_empenhado'] = despesas_df.valor_empenhado.astype('float64')
despesas_df['valor_pago'] = despesas_df.valor_pago.astype('float64')

print(despesas_df.dtypes)

despesas_df.isnull().sum()
# Out:
# ano_movimentacao                 int64
# mes_movimentacao                 int64
# orgao_codigo                     int64
# orgao_nome                      object
# unidade_codigo                 float64
# unidade_nome                    object
# categoria_economica_codigo       int64
# categoria_economica_nome        object
# grupo_despesa_codigo             int64
# grupo_despesa_nome              object
# modalidade_aplicacao_codigo      int64
# modalidade_aplicacao_nome       object
# elemento_codigo                  int64
# elemento_nome                   object
# subelemento_codigo               int64
# subelemento_nome                object
# funcao_codigo                    int64
# funcao_nome                     object
# subfuncao_codigo                 int64
# subfuncao_nome                  object
# programa_codigo                  int64
# programa_nome                   object
# acao_codigo                      int64
# acao_nome                       object
# fonte_recurso_codigo             int64
# fonte_recurso_nome              object
# empenho_ano                      int64
# empenho_modalidade_nome         object
# empenho_modalidade_codigo        int64
# empenho_numero                   int64
# subempenho                       int64
# indicador_subempenho            object
# credor_codigo                    int64
# credor_nome                     object
# modalidade_licitacao_codigo      int64
# modalidade_licitacao_nome       object
# valor_empenhado                float64
# valor_liquidado                float64
# valor_pago                     float64
# dtype: object
# ano_movimentacao               0
# mes_movimentacao               0
# orgao_codigo                   0
# orgao_nome                     0
# unidade_codigo                 0
# unidade_nome                   0
# categoria_economica_codigo     0
# categoria_economica_nome       0
# grupo_despesa_codigo           0
# grupo_despesa_nome             0
# modalidade_aplicacao_codigo    0
# modalidade_aplicacao_nome      0
# elemento_codigo                0
# elemento_nome                  0
# subelemento_codigo             0
# subelemento_nome               0
# funcao_codigo                  0
# funcao_nome                    0
# subfuncao_codigo               0
# subfuncao_nome                 0
# programa_codigo                0
# programa_nome                  0
# acao_codigo                    0
# acao_nome                      0
# fonte_recurso_codigo           0
# fonte_recurso_nome             0
# empenho_ano                    0
# empenho_modalidade_nome        0
# empenho_modalidade_codigo      0
# empenho_numero                 0
# subempenho                     0
# indicador_subempenho           0
# credor_codigo                  0
# credor_nome                    0
# modalidade_licitacao_codigo    0
# modalidade_licitacao_nome      0
# valor_empenhado                0
# valor_liquidado                0
# valor_pago                     0
# dtype: int64

# %%
gasto_por_orgao = despesas_df.groupby(['orgao_nome']).agg({'valor_pago':'sum'})

gasto_por_orgao

# gasto_por_orgao.plot.barh()
# Out:
#                                                       valor_pago
# orgao_nome
# CONTROLADORIA GERAL DO MUNICÍPIO                    7.532491e+06
# ENCARGOS GERAIS DO MUNICÍPIO                        4.009990e+08
# GABINETE DE IMPRENSA                                5.160962e+06
# GABINETE DE PROJETOS ESPECIAIS                      1.299619e+07
# GABINETE DE PROJETOS ESPECIAIS - ADMINISTRAÇÃO ...  1.010094e+06
# GABINETE DO PREFEITO                                9.407512e+06
# GABINETE DO VICE-PREFEITO                           1.562618e+06
# PROCURADORIA GERAL DO MUNICÍPIO                     3.592755e+07
# REPRESENTAÇÃO EM BRASÍLIA E RELAÇÕES INTERNACIO...  1.517611e+06
# SECRETARIA DE ADMINISTRAÇÃO E GESTÃO DE PESSOAS...  5.120112e+08
# SECRETARIA DE ASSUNTOS JURÍDICOS - ADMINISTRAÇÃ...  6.659568e+06
# SECRETARIA DE CULTURA                               3.466502e+07
# SECRETARIA DE CULTURA - ADMINISTRAÇÃO SUPERVISI...  5.742112e+07
# SECRETARIA DE DESENVOLVIMENTO SOCIAL E DIRETOS ...  3.276369e+07
# SECRETARIA DE DESENVOLVIMENTO SOCIAL, JUVENTUDE...  2.808250e+07
# SECRETARIA DE DESENVOLVIMENTO SUSTENTÁVEL E MEI...  2.072542e+07
# SECRETARIA DE DESENVOLVIMENTO SUSTENTÁVEL E MEI...  2.746645e+06
# SECRETARIA DE EDUCAÇÃO                              8.179947e+08
# SECRETARIA DE ENFRENTAMENTO AO CRACK E OUTRAS D...  1.728886e+05
# SECRETARIA DE ESPORTES                              1.422045e+04
# SECRETARIA DE ESPORTES - ADMINISTRAÇÃO SUPERVIS...  4.216214e+04
# SECRETARIA DE FINANÇAS                              5.421918e+07
# SECRETARIA DE FINANÇAS - ADMINISTRAÇÃO SUPERVIS...  6.224479e+07
# SECRETARIA DE GOVERNO E PARTICIPAÇÃO SOCIAL         3.308127e+07
# SECRETARIA DE HABITAÇÃO                             1.914500e+04
# SECRETARIA DE INFRAESTRUTURA E HABITAÇÃO            3.780982e+07
# SECRETARIA DE INFRAESTRUTURA E SERVIÇOS URBANOS...  6.459237e+08
# SECRETARIA DE JUVENTUDE E QUALIFICAÇÃO PROFISSI...  7.802920e+04
# SECRETARIA DE MOBILIDADE E CONTROLE URBANO          6.523277e+07
# SECRETARIA DE MOBILIDADE E CONTROLE URBANO - AD...  7.885422e+07
# SECRETARIA DE MULHER                                4.202163e+06
# SECRETARIA DE PLANEJAMENTO E GESTÃO                 4.244049e+04
# SECRETARIA DE PLANEJAMENTO URBANO                   9.864171e+06
# SECRETARIA DE PLANEJAMENTO, ADMINISTRAÇÃO E GES...  5.120444e+07
# SECRETARIA DE SANEAMENTO                            4.492384e+07
# SECRETARIA DE SANEAMENTO - ADMINISTRAÇÃO SUPERV...  1.666083e+06
# SECRETARIA DE SAÚDE - ADMINISTRAÇÃO SUPERVISIONADA  1.009714e+09
# SECRETARIA DE SEGURANÇA URBANA                      6.574905e+07
# SECRETARIA DE TURISMO, ESPORTES E LAZER             3.520900e+07

# %%
gasto_por_mes = despesas_df.groupby(['mes_movimentacao']).agg({'valor_pago':'sum'})

# gasto_por_mes

gasto_por_mes.plot.barh()
